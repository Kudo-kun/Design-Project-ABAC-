# %%
import numpy as np
from ml_models import models_dict
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.metrics import Precision, Recall
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
def data_preprocessor(fname):
    with open(fname, 'r') as f:
        rules = f.read().split('\n')

    X,  Y = [], []
    for rule in rules:
        (UA, OA, P) = rule.split(';')
        UA = list(map(int, UA.split(',')))
        OA = list(map(int, OA.split(',')))
        X.append([UA + OA])
        Y.append(int(P))
    return (np.array(X), np.array(Y))

# %%
def create_model(inp_shape, model_type):
    inp = Input(shape=inp_shape)
    if model_type == "LSTM":
        out = LSTM(5, return_sequences=True)(inp)
        out = Dropout(0.2)(out)
    elif model_type == "BiLSTM":
        out = Bidirectional(LSTM(5, return_sequences=True))(inp)
        out = Dropout(0.4)(out)
    elif model_type == "GRU":
        out = GRU(5, return_sequences=True)(inp)
        out = Dropout(0.2)(out)
    elif model_type == "CNN":
        out = Conv1D(5, (3), activation="relu", padding="same")(inp)
        out = Dropout(0.2)(out)
    out = Dense(1, activation="sigmoid")(out)
    model = Model(inp, out)
    return model

# %%
Xtrain, Ytrain = data_preprocessor("abac-cat-v3.txt")
Xtest, Ytest = data_preprocessor("test.txt")

# %%
model = create_model((1, 8), "CNN")
model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy", Recall(), Precision()])
hist = model.fit(Xtrain, Ytrain, batch_size=4, epochs=30, validation_data=(Xtest, Ytest))
# Out:
# Epoch 1/30
# 1008/1008 [==============================] - 3s 2ms/step - loss: 0.3721 - accuracy: 0.8482 - recall: 0.1731 - precision: 0.4050 - val_loss: 1.9311 - val_accuracy: 0.3470 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 2/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3168 - accuracy: 0.8772 - recall: 0.2915 - precision: 0.6371 - val_loss: 1.9179 - val_accuracy: 0.3480 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 3/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3124 - accuracy: 0.8792 - recall: 0.3481 - precision: 0.6254 - val_loss: 1.8131 - val_accuracy: 0.3480 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 4/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3088 - accuracy: 0.8852 - recall: 0.3922 - precision: 0.6510 - val_loss: 1.6768 - val_accuracy: 0.3520 - val_recall: 0.0061 - val_precision: 1.0000
# Epoch 5/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2972 - accuracy: 0.8909 - recall: 0.4240 - precision: 0.6780 - val_loss: 1.5369 - val_accuracy: 0.3530 - val_recall: 0.0077 - val_precision: 1.0000
# Epoch 6/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.3044 - accuracy: 0.8906 - recall: 0.4541 - precision: 0.6607 - val_loss: 1.5185 - val_accuracy: 0.3550 - val_recall: 0.0107 - val_precision: 1.0000
# Epoch 7/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2969 - accuracy: 0.8906 - recall: 0.4329 - precision: 0.6712 - val_loss: 1.3746 - val_accuracy: 0.3740 - val_recall: 0.0399 - val_precision: 1.0000
# Epoch 8/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2974 - accuracy: 0.8914 - recall: 0.4558 - precision: 0.6649 - val_loss: 1.3120 - val_accuracy: 0.3970 - val_recall: 0.0752 - val_precision: 1.0000
# Epoch 9/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2944 - accuracy: 0.8958 - recall: 0.4753 - precision: 0.6862 - val_loss: 1.2369 - val_accuracy: 0.4010 - val_recall: 0.0813 - val_precision: 1.0000
# Epoch 10/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2978 - accuracy: 0.8924 - recall: 0.4647 - precision: 0.6675 - val_loss: 1.2252 - val_accuracy: 0.4010 - val_recall: 0.0813 - val_precision: 1.0000
# Epoch 11/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2935 - accuracy: 0.8934 - recall: 0.4664 - precision: 0.6735 - val_loss: 1.1399 - val_accuracy: 0.4030 - val_recall: 0.0844 - val_precision: 1.0000
# Epoch 12/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2941 - accuracy: 0.8921 - recall: 0.4611 - precision: 0.6675 - val_loss: 0.9758 - val_accuracy: 0.4440 - val_recall: 0.1472 - val_precision: 1.0000
# Epoch 13/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2905 - accuracy: 0.8953 - recall: 0.4770 - precision: 0.6818 - val_loss: 1.0298 - val_accuracy: 0.4170 - val_recall: 0.1058 - val_precision: 1.0000
# Epoch 14/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2953 - accuracy: 0.8983 - recall: 0.4947 - precision: 0.6931 - val_loss: 0.9864 - val_accuracy: 0.4380 - val_recall: 0.1380 - val_precision: 1.0000
# Epoch 15/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2919 - accuracy: 0.9003 - recall: 0.4947 - precision: 0.7071 - val_loss: 0.9567 - val_accuracy: 0.4620 - val_recall: 0.1748 - val_precision: 1.0000
# Epoch 16/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2920 - accuracy: 0.8943 - recall: 0.4647 - precision: 0.6813 - val_loss: 0.9570 - val_accuracy: 0.4710 - val_recall: 0.1887 - val_precision: 1.0000
# Epoch 17/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2940 - accuracy: 0.8929 - recall: 0.4594 - precision: 0.6736 - val_loss: 0.8851 - val_accuracy: 0.5820 - val_recall: 0.3589 - val_precision: 1.0000
# Epoch 18/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2887 - accuracy: 0.8988 - recall: 0.4947 - precision: 0.6965 - val_loss: 0.9007 - val_accuracy: 0.5860 - val_recall: 0.3650 - val_precision: 1.0000
# Epoch 19/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2878 - accuracy: 0.8968 - recall: 0.4717 - precision: 0.6953 - val_loss: 0.8184 - val_accuracy: 0.6560 - val_recall: 0.4724 - val_precision: 1.0000
# Epoch 20/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2875 - accuracy: 0.8961 - recall: 0.4788 - precision: 0.6861 - val_loss: 0.7593 - val_accuracy: 0.7190 - val_recall: 0.5721 - val_precision: 0.9947
# Epoch 21/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2878 - accuracy: 0.8968 - recall: 0.4788 - precision: 0.6913 - val_loss: 0.7515 - val_accuracy: 0.7290 - val_recall: 0.5890 - val_precision: 0.9922
# Epoch 22/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2836 - accuracy: 0.8983 - recall: 0.4788 - precision: 0.7021 - val_loss: 0.7484 - val_accuracy: 0.7240 - val_recall: 0.5890 - val_precision: 0.9796
# Epoch 23/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2862 - accuracy: 0.8988 - recall: 0.4912 - precision: 0.6985 - val_loss: 0.7573 - val_accuracy: 0.7250 - val_recall: 0.5828 - val_precision: 0.9922
# Epoch 24/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2867 - accuracy: 0.8996 - recall: 0.4982 - precision: 0.6998 - val_loss: 0.7424 - val_accuracy: 0.7060 - val_recall: 0.5675 - val_precision: 0.9686
# Epoch 25/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2868 - accuracy: 0.8996 - recall: 0.4876 - precision: 0.7059 - val_loss: 0.7337 - val_accuracy: 0.7200 - val_recall: 0.5859 - val_precision: 0.9745
# Epoch 26/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2823 - accuracy: 0.9008 - recall: 0.4876 - precision: 0.7150 - val_loss: 0.6862 - val_accuracy: 0.7550 - val_recall: 0.6564 - val_precision: 0.9532
# Epoch 27/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2871 - accuracy: 0.8976 - recall: 0.4735 - precision: 0.6997 - val_loss: 0.6442 - val_accuracy: 0.7720 - val_recall: 0.6902 - val_precision: 0.9454
# Epoch 28/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2883 - accuracy: 0.8973 - recall: 0.5053 - precision: 0.6810 - val_loss: 0.6526 - val_accuracy: 0.7580 - val_recall: 0.6733 - val_precision: 0.9380
# Epoch 29/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2840 - accuracy: 0.8998 - recall: 0.4753 - precision: 0.7154 - val_loss: 0.5967 - val_accuracy: 0.7720 - val_recall: 0.6979 - val_precision: 0.9362
# Epoch 30/30
# 1008/1008 [==============================] - 1s 1ms/step - loss: 0.2871 - accuracy: 0.8996 - recall: 0.4876 - precision: 0.7059 - val_loss: 0.6102 - val_accuracy: 0.7690 - val_recall: 0.6917 - val_precision: 0.9376

# %%
x = range(1, 31)
plt.plot(x, hist.history["accuracy"], color='r', label="training")
plt.plot(x, hist.history["val_accuracy"], color='b', label="validation")
plt.title("Training metric: Accuracy")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend(loc="best")
plt.show()

# %%
plt.plot(x, hist.history["precision"], color='r', label="training")
plt.plot(x, hist.history["val_precision"], color='b', label="validation")
plt.title("Training metric: Precision")
plt.xlabel("epochs")
plt.ylabel("precision")
plt.legend(loc="best")
plt.show()

# %%
plt.plot(x, hist.history["recall"], color='r', label="training")
plt.plot(x, hist.history["val_recall"], color='b', label="validation")
plt.title("Training metric: Recall")
plt.xlabel("epochs")
plt.ylabel("recall")
plt.legend(loc="best")
plt.show()

# %%
f1score_compute = lambda pre, rec : [(2*x*y)/(x+y) if (x+y != 0) else 0 for (x, y) in zip(pre, rec)]

f1score = f1score_compute(hist.history["precision"], hist.history["recall"])
val_f1score = f1score_compute(hist.history["val_precision"], hist.history["val_recall"])
plt.plot(x, f1score, color='r', label="training")
plt.plot(x, val_f1score, color='b', label="validation")
plt.title("Training metric: F1Score")
plt.xlabel("epochs")
plt.ylabel("f1score")
plt.legend(loc="best")
plt.show()
